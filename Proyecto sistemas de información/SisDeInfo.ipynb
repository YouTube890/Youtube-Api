# %%
import pandas as pd
import numpy as np

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
Al = gc.open('SisDeInfo').worksheet('Al')
Bra = gc.open('SisDeInfo').worksheet('Bra')
Can = gc.open('SisDeInfo').worksheet('Can')
Col = gc.open('SisDeInfo').worksheet('Col')
EU = gc.open('SisDeInfo').worksheet('EU')
GB = gc.open('SisDeInfo').worksheet('GB')

# %%
pip install 'fsspec>=0.3.3'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import dask.dataframe as dd

# %%
df_Al = dd.read_csv('/content/drive/MyDrive/SistemasDeInfo/Alemania.csv',
                     sep = ';',
                     encoding = 'latin-1')
df_Al.head()

# %%
df_Bra = dd.read_csv('/content/drive/MyDrive/SistemasDeInfo/Brazil.csv',
                     sep = ';',
                     encoding = 'latin-1')
df_Bra.head()
# Out:
#       video_id  ...                                        description
# 0  XtjbXT_91T0  ...  Se vc curtiu deixa aÃ­ nos comentÃ¡rios que eu...
# 1  _NyHA0j3Uak  ...  O cantor MaurÃ­lio Delmont Ribeiro, de 28 anos...
# 2  ZnZNhITxSwk  ...  VÃ­deo clipe oficial âDama de Vermelhoâ de...
# 3  ZbNk4ELd9NI  ...  VIREI DONA DE UMA SORVETERIA DE VERDADE POR UM...
# 4  wAt2-Elkgn0  ...  ð· MEU INSTAGRAM: https://www.instagram.com/...
#
# [5 rows x 16 columns]

# %%
cat = pd.DataFrame(df_Bra.groupby('categoryId').categoryId.count().compute().sort_values(ascending = False)).rename(columns = {'categoryId':'Count'})
cat.reset_index(level = 0, inplace = True)
Bra.update('A1',[cat.columns.values.tolist()] + cat.values.tolist())
# Out:
# {'spreadsheetId': '1fODzjTuqIFEXPV0A8Q1PxdkBjHXW5XAnzY7OIyydtfY',
#  'updatedCells': 30,
#  'updatedColumns': 2,
#  'updatedRange': 'Bra!A1:B15',
#  'updatedRows': 15}

# %%
df_Can = dd.read_csv('/content/drive/MyDrive/SistemasDeInfo/Canada.csv',
                     sep = ';',
                     encoding = 'latin-1')
df_Can.head()
# Out:
#       video_id  ...                                        description
# 0  0BYobDZutZY  ...  Part 1: Asking her to be my Girlfriend: https:...
# 1  4XmgqWXBnRA  ...  Vaat laga denge!â¡Presenting to you the most ...
# 2  lz9_fhZlu5Y  ...                                                NaN
# 3  bvWRMAU6V-c  ...  See Disneyâs Encanto now streaming on Disney...
# 4  JapWzIV1XDw  ...  Please visit http://ayylienclothing.com and ge...
#
# [5 rows x 16 columns]

# %%
len(df_Can)
# Out:
# 2164

# %%
df_Col = dd.read_csv('/content/drive/MyDrive/SistemasDeInfo/Colombia.csv',
                     sep = ';',
                     encoding = 'latin-1')
df_Col.head()
# Out:
#       video_id  ...                                        description
# 0  f2VRdJU30lA  ...  AlemÃ¡nMi Sangre Derramada Sobre el Hip Hop Le...
# 1  6IteX4haYlE  ...  30 cosas que quizÃ¡s no sabÃ­as de Encanto | 3...
# 2  BaKGBkFkz1Q  ...  No olviden suscribirse!!!! #short #ytshort #co...
# 3  qJ5Lce5CF-U  ...                                                NaN
# 4  wsRFEWAuuJ8  ...  Hoy os traigo el primero de 3 vÃ­deos acerca d...
#
# [5 rows x 16 columns]

# %%
df_EU = dd.read_csv('/content/drive/MyDrive/SistemasDeInfo/Estados Unidos.csv',
                     sep = ';',
                     encoding = 'latin-1',
                     dtype={'categoryId': 'object'})
df_EU.head()
# Out:
#       video_id  ...                                        description
# 0  7VHfzUhRTFo  ...  Learning the secret technique was definitely w...
# 1  xbV1csSM8OE  ...                         instagram: @PontiacMadeDDG
# 2  GmX7R9GXcpY  ...  Five Nights at Freddy's Security Breach is pac...
# 3  vGCCtFIzjwo  ...                                            #shorts
# 4  XGuW5UKSIcY  ...  This VR game went OFF THE RAILS ð | #shorts...
#
# [5 rows x 16 columns]

# %%
df_GB = dd.read_csv('/content/drive/MyDrive/SistemasDeInfo/Gran Bretaña.csv',
                     sep = ';',
                     encoding = 'latin-1',
                     dtype={'categoryId': 'object'})
df_GB.head()
# Out:
#       video_id  ...                                        description
# 0  73bjnNCOc4M  ...                                                NaN
# 1  oTwjgtWESrU  ...                                                NaN
# 2  lz9_fhZlu5Y  ...                                                NaN
# 3  0BYobDZutZY  ...  Part 1: Asking her to be my Girlfriend: https:...
# 4  pIUeTlmHF3M  ...  SUBSCRIBE âº http://bit.ly/SSFootballSubPREMI...
#
# [5 rows x 16 columns]

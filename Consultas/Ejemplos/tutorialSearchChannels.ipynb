# %% [markdown]
# ### Getting Started

# %%
api_key = "AIzaSyDqq-BEw8S5_mJq60d5QGZcBv13Gyu6qiw"

# %%
pip install google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube','v3',developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %% [markdown]
# ### Searching Content

# %%
req = youtube.search().list(q='avengers',part='snippet',type='video',maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'GpXwwgbq88BWvU8VpT54Kdtvrjw',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'CO',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '_8oxIctcGjvgWTKiQ1EsPJLWdU8',
#    'id': {'kind': 'youtube#video', 'videoId': 'BNGsWaJKYU0'},
#    'snippet': {'publishedAt': '2019-10-11T04:29:35Z',
#     'channelId': 'UCr2ibA5j6EzAlK9Owxe6Vbg',
#     'title': 'THE ACADEMY 🖤(Álbum Completo)🖤🔥 Rich Music🔥',
#     'description': 'Créditos a @richmusic.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Krimx Araya',
# ...

# %%
res['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': '_8oxIctcGjvgWTKiQ1EsPJLWdU8',
#   'id': {'kind': 'youtube#video', 'videoId': 'BNGsWaJKYU0'},
#   'snippet': {'publishedAt': '2019-10-11T04:29:35Z',
#    'channelId': 'UCr2ibA5j6EzAlK9Owxe6Vbg',
#    'title': 'THE ACADEMY 🖤(Álbum Completo)🖤🔥 Rich Music🔥',
#    'description': 'Créditos a @richmusic.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Krimx Araya',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-10-11T04:29:35Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'AiKXp6Vu3wprOyw4qyOlB48CHD8',
#   'id': {'kind': 'youtube#video', 'videoId': '5FgZNCgVFkM'},
# ...

# %%
# ver el primero 
res['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '_8oxIctcGjvgWTKiQ1EsPJLWdU8',
#  'id': {'kind': 'youtube#video', 'videoId': 'BNGsWaJKYU0'},
#  'snippet': {'publishedAt': '2019-10-11T04:29:35Z',
#   'channelId': 'UCr2ibA5j6EzAlK9Owxe6Vbg',
#   'title': 'THE ACADEMY 🖤(Álbum Completo)🖤🔥 Rich Music🔥',
#   'description': 'Créditos a @richmusic.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/BNGsWaJKYU0/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Krimx Araya',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2019-10-11T04:29:35Z'}}

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# THE ACADEMY 🖤(Álbum Completo)🖤🔥 Rich Music🔥
# Avengers Endgame Final Battle Fight Scene Thanos Vs Avengers Ending Scene IMAX
# Captain America &quot;Avengers Assemble&quot; Scene - Portal Scene - Avengers : Endgame (2019) Scene
# The Avengers - &quot;I&#39;m Always Angry&quot; - Hulk SMASH Scene - Movie CLIP HD
# Avengers Infinity War Final Battle Thanos Vs Avengers Wakanda Fight Scenes And Ending
# Thor vs Hulk - Fight Scene - The Avengers (2012) Movie Clip HD
# MARVEL&#39;S AVENGERS - Pelicula Completa en Español - Historia 2020 PS4 Pro
# Team Iron Man vs Team Cap - Airport Battle Scene - Captain America: Civil War - Movie CLIP HD
# Avengers VS Squid Game!
# Hulk VS The Avengers
# Avengers Infinity War Full Movie facts | Thanos | Thor | Iron Man | Avengers 3: Infinity War
# The Avengers subtitle indonesia part 2 (SUPERCUT)
# Avengers Assemble Scene - The Avengers (2012) Movie Clip HD
# Iron Man Nuke Scene Hulk Saves Iron Man | The Avengers Movie Clip 4K
# ...

# %% [markdown]
# ### Searching Oldest Youtube Videos

# %%
from datetime import datetime

datetime(year=2005, month=1, day=1)
# Out:
# datetime.datetime(2005, 1, 1, 0, 0)

# %%
datetime(year=2005, month=1, day=1).isoformat()
# Out:
# '2005-01-01T00:00:00'

# %%
datetime(year=2005, month=1, day=1).strftime('%Y-%m-%dT%H:%SZ')
# Out:
# '2005-01-01T00:00Z'

# %%
# La api pide adicionarle la Z al final y el formato RFC 3339
start_time=datetime(year=2005, month=1, day=1).isoformat()+'Z'
end_time = datetime(year=2006, month=1, day=1).isoformat()+'Z'

# %%
req = youtube.search().list(
    q='python programming',
    part='snippet',
    type='video',
    maxResults=50,
    publishedAfter=start_time,
    publishedBefore=end_time)
res = req.execute()
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '1aEI_q7vyyMSaJ3p9XsmB_0RBJM',
#  'regionCode': 'CO',
#  'pageInfo': {'totalResults': 13, 'resultsPerPage': 11},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'gMIEAPqDtvFIGyuTPSgneZrQI84',
#    'id': {'kind': 'youtube#video', 'videoId': 'Gzj723LkRJY'},
#    'snippet': {'publishedAt': '2005-11-08T07:45:46Z',
#     'channelId': 'UCKS1lbJXYQxwqpFzHMiYinQ',
#     'title': 'Ruby on Rails demo',
#     'description': 'David Heinemeier Hansson, the creator of the Ruby on Rails web development framework demonstrates how to create a blog ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Gzj723LkRJY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Gzj723LkRJY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Gzj723LkRJY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
# ...

# %%
for item in res['items']:
    print(item['snippet']['title'],"..." ,item['snippet']['publishedAt'],"...",item['id']['videoId'])
# Out:
# Ruby on Rails demo ... 2005-11-08T07:45:46Z ... Gzj723LkRJY
# CFEclipse Snips and Navigator ... 2005-07-07T05:54:24Z ... 4CfHtCQp7ys
# Assembly forum tutorial ... 2005-12-21T03:14:45Z ... a-UUg1JU-nc
# whistle ... 2005-12-27T08:04:26Z ... QnkwMKMSDeI
# Lovely Bunch Of Coconuts! ... 2005-12-11T03:23:55Z ... eEZNdRgOUWM
# Creating a gesture for closing tab in Firefox ... 2005-09-13T12:09:55Z ... QSypQglf4nI
# Installation apache for windows ... 2005-10-30T23:36:24Z ... 3fAG37ZRiv4
# Berca ... 2005-12-28T13:27:11Z ... bCsBC-BHMIY
# Marian Seniors Oh Holy Night ... 2005-12-12T06:57:43Z ... Kfo6E9MbvJ0
# PHP HISTORY ... 2005-12-10T10:27:34Z ... sSXUCtciAtk
# Hak5 - Episode #5 ... 2005-12-06T20:16:49Z ... KL2qa_3JpAk

# %% [markdown]
# ### Fetching All Videos of a Channel

# %%
req2 = youtube.channels().list(
    forUsername='UNsedebogota',
    part='contentDetails'
    )
res = req2.execute()
res
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'AKa_SF-zFfRwxvK__G9xst8sfys',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'FB2iu-U1DMkksXsSJi7XpFY5Wuk',
#    'id': 'UCJRDA71lUxQ8lwgPqIfW89g',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUJRDA71lUxQ8lwgPqIfW89g'}}}]}

# %%
req3 = youtube.playlistItems().list(
    playlistId='UUJRDA71lUxQ8lwgPqIfW89g',
    part='snippet',
    maxResults=50)
res = req3.execute()
res
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'TlaS8t4RH21dbuONhwIjxfEXr7Q',
#  'nextPageToken': 'EAAaBlBUOkNESQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'mf8nf5CUTVbn3HZfm2K8BliC47Q',
#    'id': 'VVVKUkRBNzFsVXhROGx3Z1BxSWZXODlnLldWVmRDMlNtN3NF',
#    'snippet': {'publishedAt': '2021-12-16T13:32:57Z',
#     'channelId': 'UCJRDA71lUxQ8lwgPqIfW89g',
#     'title': 'Historia del Edificio de Bellas Artes de la UNALBogotá',
#     'description': 'Esta semana la Sede Bogotá entregó, para su cuidado por parte de la Comunidad Universitaria, el Edificio de Bellas Artes. Con esta renovación, se devuelve a la ciudad uno de sus edificios más emblemáticos, mientras que el campus recupera un espacio que ha sobresalido siempre por ser un laboratorio de creación, experimentación e innovación.\n\nEn este video te contamos su historia y los resultados de esta recuperación integral.\n\nConoce más de esta historia en https://bogota.unal.edu.co/edificio-bellas-artes/',
# ...

# %% [markdown]
# #### Función que da la lista de los videos en un canal

# %%
from apiclient.discovery import build

api_key = "AIzaSyDqq-BEw8S5_mJq60d5QGZcBv13Gyu6qiw"
youtube = build('youtube','v3',developerKey=api_key)

channel_id = 'UNsedebogota'

def get_channel_videos(channel_id):
    res =  youtube.channels().list(forUsername=channel_id,
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId = playlist_id,
                                          part='snippet',
                                          maxResults=50,
                                          pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
        
    return videos

videos = get_channel_videos(channel_id)

for video in videos:
    print(video['snippet']['title'])
# Out:
# Historia del Edificio de Bellas Artes de la UNALBogotá
# Balance final del año y de los #EncuentrosVRI 2021 - #UNALBogotá
# Ceremonia entrega de distinciones para egresados y administrativos - 2021
# No dejes de vacunarte. Acércate a la Hemeroteca de la UNALBogotá
# Conozca la historia del estadio Alfonso López
# Foro Candidatos Representación Estudiantil de Pregrado ante el Consejo de Sede - 2021
# #ComunidadUNAL #Bogotá ¡Bienvenida a un campus seguro y amable!
# Conoce la historia de la Oficina 012 del Banco Popular ubicada en la UNALBogotá
# La pandemia nos cambió, el Retorno Seguro nos permitirá encontarnos
# Docente UNAL: seguimos estas recomendaciones porque somos los líderes del Retorno Seguro a la Sede
# ¡Ya retornamos al Campus! Ten en cuenta estas recomendaciones para tener un Retorno Seguro.
# ¡La  Sede Bogotá obtuvo renovación de la ISO 14001!
# Palabras de bienvenida para los estudiantes nuevo de la Sede
# ¡Asi retorna a actividades el Jardín Infantil de la Sede Bogotá!
# ...

# %%
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'mf8nf5CUTVbn3HZfm2K8BliC47Q',
#   'id': 'VVVKUkRBNzFsVXhROGx3Z1BxSWZXODlnLldWVmRDMlNtN3NF',
#   'snippet': {'publishedAt': '2021-12-16T13:32:57Z',
#    'channelId': 'UCJRDA71lUxQ8lwgPqIfW89g',
#    'title': 'Historia del Edificio de Bellas Artes de la UNALBogotá',
#    'description': 'Esta semana la Sede Bogotá entregó, para su cuidado por parte de la Comunidad Universitaria, el Edificio de Bellas Artes. Con esta renovación, se devuelve a la ciudad uno de sus edificios más emblemáticos, mientras que el campus recupera un espacio que ha sobresalido siempre por ser un laboratorio de creación, experimentación e innovación.\n\nEn este video te contamos su historia y los resultados de esta recuperación integral.\n\nConoce más de esta historia en https://bogota.unal.edu.co/edificio-bellas-artes/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WVVdC2Sm7sE/default.jpg',
#      'width': 120,
#      'height': 90},
# ...
